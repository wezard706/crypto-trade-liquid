# %%
import os
import sys
import pickle
import pandas as pd
import numpy as np
import talib as ta
from datetime import datetime, timedelta
#%matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image, display_png
os.chdir('/home/shun/PycharmProjects/crypto-onibot')

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_colwidth', 1000)

# %%
def generate_ticker(executions):
    '''
    約定履歴から1秒ごとのtickerを作成
    約定履歴: timestamp, side, price, amount
    ticker: timestamp, bid, bid_volume, ask, ask_volume, open, high, low, close, volume
    '''
    executions.index = pd.to_datetime(executions.timestamp.apply(lambda x: datetime.fromtimestamp(x/1000)))

    executions = executions.resample('S').last()
    
    # bid, askを算出
    bids = executions.loc[executions.side == 'Sell'].resample('S').ffill()
    bids = bids.drop(['timestamp', 'side'], axis=1)
    asks = executions.loc[executions.side == 'Buy'].resample('S').ffill()
    asks = asks.drop(['timestamp', 'side'], axis=1)
    bids_asks = pd.merge(bids, asks, how='inner', left_index=True, right_index=True)
    bids_asks.columns = ['bid', 'bid_volume', 'ask', 'ask_volume']
    # OHLCVを算出   
    ohlcv = bids.price.resample('S').ohlc()
    ohlcv['volume'] = bids.amount.resample('S').sum()
    ohlcv['timestamp'] = pd.Series(ohlcv.index).apply(lambda x: datetime.timestamp(x) * 1000).values    
    # ticker作成
    ticker = pd.merge(bids_asks, ohlcv, how='inner', left_index=True, right_index=True)
    ticker['timestamp'] = pd.Series(ticker.index).apply(lambda x: datetime.timestamp(x) * 1000).values
    return ticker.reset_index(drop=True).ix[:, ['timestamp', 'bid', 'bid_volume', 'ask', 'ask_volume', 'open', 'high', 'low', 'close', 'volume']]

def generate_ohlcv(executions, candle_type):
    '''
    約定履歴から１分、５分、１時間のOHLCVを作成
    約定履歴: timestamp, side, price, amount
    OHLCV: timestamp, bid, bid_volume, ask, ask_volume, open, high, low, close, volume
    '''        
    executions.index = pd.to_datetime(executions.timestamp.apply(lambda x: datetime.fromtimestamp(x/1000)))

    # 1秒ごとにグルーピング
    executions = executions.resample('S').last()

    # bid, askを算出
    bids = executions.loc[executions.side == 'Sell'].resample('S').ffill()
    
    # OHLCVを作成
    if candle_type == '1s':
        freq = 'S'
    if candle_type == '1m':
        freq = 'T'
    elif candle_type == '5m':
        freq = '5T'
    elif candle_type == '1h':
        freq = 'H'
    
    ohlcv = bids.price.resample(freq).ohlc()
    ohlcv['volume'] = bids.amount.resample(freq).sum()
    ohlcv['timestamp'] = pd.Series(ohlcv.index).apply(lambda x: datetime.timestamp(x) * 1000).values
    return ohlcv

def generate_active_ohlcv(df, candle_type):
    '''
    1秒足から未確定足を含むOHLCVを作成
    df: DataFrame (index: datetimeindex, column: open, high, low, close, volume timestamp)
    candle_type: '1m' or '5m' or '1h'
    '''
    
    ohlcv = df.values
    open = ohlcv[0, 0]
    high = -1
    low = 999999
    close = ohlcv[0, 3]
    volume = ohlcv[0, 4]

    if candle_type == '1m':
        div = 60 * 1000
    elif candle_type == '5m':
        div = 60 * 5 * 1000
    elif candle_type == '1h':
        div = 60 * 60 * 1000
    
    active_ohlcv = []   
    for i in range(ohlcv.shape[0]):    
        row = ohlcv[i]

        # １分ごとにリセット
        timestamp = row[5]
        if timestamp % div == 0:
            open = row[0]
            high = -1
            low = 999999
            volume = 0

        close = row[3]
        volume += row[4]
        if row[1] > high:
            high = row[1]
        if row[2] < low:
            low = row[2]
        active_ohlcv.append([open, high, low, close, volume, timestamp])
        
    active_ohlcv = pd.DataFrame(active_ohlcv)
    active_ohlcv.columns = ['open', 'high', 'low', 'close', 'volume', 'timestamp']
    active_ohlcv.index = pd.to_datetime(active_ohlcv.timestamp.apply(lambda x: datetime.fromtimestamp(x / 1000)))
    return active_ohlcv

def generate_orderbook(executions):
    executions.index = pd.to_datetime(executions.timestamp.apply(lambda x: datetime.fromtimestamp(x/1000)))

    # 1秒ごとにグルーピング（nullは前回の値で補完）
    orderbook = executions.resample('S').ffill()
    orderbook['timestamp'] = pd.Series(orderbook.index).apply(lambda x: datetime.timestamp(x) * 1000).values

    # 指定範囲のデータを取り出す
    orderbook = orderbook.loc[(start_dt <= orderbook.index) & (orderbook.index < end_dt)]

# %%
import os
import fnmatch
from common.utils import str2dt, format_dt

def read_csvs(dirpath, start_dt, end_dt, pattern=None, prefix=None):
    files = sorted(os.listdir(dirpath))

    if pattern is not None:
        files = [file for file in files if fnmatch.fnmatch(file, pattern)]
    
    ret = None
    for file in files:
        if prefix is None:            
            dt = datetime.strptime(file, '%Y%m%d%H%M%S')
        else:
            dt = datetime.strptime(file.replace(prefix, ''), '%Y%m%d%H%M%S')
        
        if (start_dt <= dt) and (dt <= end_dt):
            print('read file: {}'.format(file))
            df = pd.read_csv(os.path.join(dirpath, file), header=None)            
            
            if ret is None:
                ret = df
            else:
                ret = pd.concat([ret, df])
    return ret

# %%
#executions = pd.read_csv('collect/executions/201903250100', names=['timestamp', 'datetime_unix', 'side', 'price', 'amount', 'datetime_jst', 'datetime_jst'])
start_dt = str2dt('2019-04-06 19:00:00')
end_dt = str2dt('2019-04-06 21:00:00')
executions = read_csvs('collect/executions', start_dt, end_dt, pattern='execution.*', prefix='execution.')
executions.columns = ['timestamp', 'datetime_utc_bitmex', 'side', 'price', 'amount', 'datetime', 'datetime_jst_bitmex']
executions = executions.drop(['datetime', 'datetime_utc_bitmex', 'datetime_jst_bitmex'], axis=1)
# 後で消す
executions['side'] = executions['side'].str.replace(' ', '')

ticker = generate_ticker(executions)
ohlcv = generate_ohlcv(executions, candle_type='1s')
active_ohlcv_1m = generate_active_ohlcv(ohlcv, candle_type='1m')
active_ohlcv_5m = generate_active_ohlcv(ohlcv, candle_type='5m')
active_ohlcv_1h = generate_active_ohlcv(ohlcv, candle_type='1h')
# Out:
# read file: execution.20190406193436
# read file: execution.20190406203441
# /home/shun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
header = ['timestamp']
for i in range(25):
    for col in ['amount', 'price']:
        header.append(col + '{0:02d}'.format(i))
        
bids = read_csvs('collect/orderbook/bids', start_dt, end_dt, pattern='bid.*', prefix='bid.')
bids.columns = header
bids.index = pd.to_datetime(bids.timestamp.apply(lambda x: datetime.fromtimestamp(x/1000)))
bids = bids.resample('S').last()

asks = read_csvs('collect/orderbook/asks', start_dt, end_dt, pattern='ask.*', prefix='ask.')
asks.columns = header
asks.index = pd.to_datetime(asks.timestamp.apply(lambda x: datetime.fromtimestamp(x/1000)))
asks = asks.resample('S').last()
# Out:
# read file: bid.20190406193631
# read file: bid.20190406203631
# (7196, 51)

# %%
inago = pd.read_csv('collect/inago/inago.csv', sep='\t', names=['id', 'board_name', 'taker_side', 'volume', 'last_price', 'pair_currency', 'from_unix_time', 'to_unix_time', 'from_datetime', 'to_datetime', 'timestamp'])
inago.index = pd.to_datetime(inago.timestamp.apply(lambda x: datetime.fromtimestamp(x/1000)))

# 1秒ごとにサンプリング
# freq format: https://stackoverflow.com/questions/35339139/where-is-the-documentation-on-pandas-freq-tags
inago = inago.resample('S').last()
inago['timestamp'] = pd.Series(inago.index).apply(lambda x: datetime.timestamp(x) * 1000).values
# 指定範囲のデータを取り出す
inago = inago.loc[(start_dt <= inago.index) & (inago.index < end_dt)]

# %%
inago
# Out:
#                          id     board_name taker_side  volume  last_price  \
# timestamp
# 2019-04-06 19:00:00     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:01     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:02     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:03     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:04     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:05     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:06     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:07     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:08     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:09     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:10     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:11     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:12     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:13     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:14     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:15     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:16     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:17     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:18     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:19     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:20     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:21     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:22     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:23     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:24     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:25     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:26     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:27     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:28     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:29     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:30     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:31     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:32     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:33     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:34     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:35     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:36     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:37     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:38     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:39     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:40     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:41     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:42     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:43     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:44     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:45     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:46     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:47     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:48     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:49     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:50     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:51     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:52     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:53     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:54     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:55     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:56     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:57     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:58     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:00:59     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:00     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:01     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:02     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:03     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:04     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:05     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:06     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:07     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:08     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:09     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:10     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:11     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:12     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:13     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:14     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:15     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:16     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:17     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:18     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:19     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:20     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:21     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:22     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:23     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:24     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:25     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:26     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:27     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:28     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:29     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:30     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:31     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:32     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:33     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:34     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:35     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:36     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:37     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:38     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:39     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:40     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:41     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:42     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:43     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:44     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:45     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:46     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:47     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:48     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:49     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:50     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:51     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:52     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:53     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:54     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:55     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:56     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:57     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:58     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:01:59     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:00     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:01     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:02     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:03     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:04     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:05     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:06     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:07     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:08     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:09     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:10     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:11     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:12     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:13     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:14     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:15     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:16     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:17     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:18     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:19     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:20     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:21     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:22     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:23     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:24     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:25     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:26     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:27     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:28     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:29     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:30     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:31     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:32     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:33     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:34     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:35     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:36     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:37     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:38     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:39     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:40     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:41     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:42     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:43     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:44     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:45     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:46     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:47     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:48     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:49     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:50     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:51     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:52     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:53     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:54     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:55     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:56     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:57     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:58     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:02:59     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:00     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:01     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:02     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:03     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:04     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:05     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:06     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:07     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:08     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:09     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19:03:10     NaN            NaN        NaN     NaN         NaN
# 2019-04-06 19
  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:04                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:05                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:06                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:07                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:08                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:09                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:10                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:11                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:12                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:13                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:14                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:15                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:16                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:17                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:18                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:19                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:20                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:21                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:22                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:23                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:24                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:25                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:26                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:27                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:28                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:29                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:30                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:31                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:32                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:33                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:34                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:35                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:36                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:37                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:38                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:39                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:40                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:41                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:42                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:43                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:44                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:45                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:46                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:47                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:48                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:49                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:50                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:51                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:52                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:53                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:54                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:55                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:56                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:57                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:58                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:58:59                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:00                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:01                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:02                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:03                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:04                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:05                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:06                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:07                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:08                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:09                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:10                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:11                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:12                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:13                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:14                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:15                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:16                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:17                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:18                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:19                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:20                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:21                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:22                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:23                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:24                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:25                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:26                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:27                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:28                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:29                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:30                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:31                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:32                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:33                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:34                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:35                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:36                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:37                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:38                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:39                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:40                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:41                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:42                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:43                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:44                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:45                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:46                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:47                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:48                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:49                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:50                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:51                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:52                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:53                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:54                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:55                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:56                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:57                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:58                  NaN                  NaN  1.554552e+12
# 2019-04-06 20:59:59  2019-04-06 20:59:41  2019-04-06 20:59:59  1.554552e+12
#
# [7200 rows x 11 columns]

# %%
ticker.to_csv('collect/format_data/ticker.csv', index=False)
ohlcv_1m.to_csv('collect/format_data/ohlcv_1m.csv', index=False)
ohlcv_5m.to_csv('collect/format_data/ohlcv_5m.csv', index=False)
ohlcv_1h.to_csv('collect/format_data/ohlcv_1h.csv', index=False)
orderbook.to_csv('collect/format_data/orderbook.csv', index=False)
inago.to_csv('collect/format_data/inago.csv', index=False)

# %% [markdown]
# # API調査

# %%
from trade_tools.my_api import API

EXCHANGE_NAME = 'bitmex'
PAIR = 'BTC/USD'
CANDLE_TYPE = '1m'
MAX_WAIT_TIME = 300
API = API(EXCHANGE_NAME)

# %%
tmp = orderbook.iloc[0]

bids = []
asks = []
for i in range(25):
    i_bid = 25 + i
    bid = tmp['price' + '{0:02d}'.format(i_bid)]
    bid_volume = tmp['amount' + '{0:02d}'.format(i_bid)]
    bids.append([bid, bid_volume])

    i_ask = 24 - i
    ask = tmp['price' + '{0:02d}'.format(i_ask)]
    ask_volume = tmp['amount' + '{0:02d}'.format(i_ask)]
    asks.append([ask, ask_volume])
formatted_orderbook = {'bids': bids, 'asks': asks, 'timestamp': tmp.timestamp}

# %%
dict(ticker.iloc[0])

# %%
orderbook.head()

# %%
API.fetch_ticker(PAIR)

# %%
datetime.fromtimestamp(datetime.now().timestamp() - 3600)

# %%
ohlcv_1m.head()

# %%
now = datetime.now()

# %%
now_timestamp = now.timestamp() * 1000

# %%
now

# %%
datetime.fromtimestamp(1553151600)

# %%
inago[~inago.id.isnull()]

# %%
orderbook1.head()

# %%
orderbook0.loc[orderbook0.side42 == 'Sell', ['side42', 'price42']]

# %%
orderbook0.iloc[4850:4860]
